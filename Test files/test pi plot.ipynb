# %%
import pandas as pd
import matplotlib.pyplot as plot
language = [0,3,0,4,5,6,7,3,4,0,0]
codingLanguages = [
        'Python',
        'Javascript',
        'Java',
        'C/C++',
        'C#',
        'SQL',
        'PHP',
        'Matlab',
        'Swift',
        'Kotlin',
        'Assembly',
]

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(32, 8), subplot_kw=dict(aspect="equal"))

recipe = ["1 cl. Vanilla Concentrate ",
          "8 cl. Orange Juice",
          "8 cl. Pineapple Juice",
          "4 cl. orgeat Syrup"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [' '.join(x.split()[-2:]) for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} cl.)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=10, weight="bold")

ax.set_title("TIE-BREAK ALCOOL FREE COCKTAIL RECIPE")

plt.show()

# %%
language = [0,3,0,4,5,6,7,3,4,0,0]
codingLanguages = [
        'Python',
        'Javascript',
        'Java',
        'C/C++',
        'C#',
        'SQL',
        'PHP',
        'Matlab',
        'Swift',
        'Kotlin',
        'Assembly',
]
df = pd.DataFrame(data = {"Number":language}, index= codingLanguages)
#plt = df.plot.pie(x = "languages", y = "Number", title = "Languages from Indeed",legend = False)
#plt = df.plot.pie(x = "languages", y = "Number", title = "Languages from Indeed",legend = False)

#credit to this thred for the percentages https://stackoverflow.com/questions/72338356/how-to-show-values-in-pandas-pie-chart
df
# Out:
#             Number
# Python           0
# Javascript       3
# Java             0
# C/C++            4
# C#               5
# SQL              6
# PHP              7
# Matlab           3
# Swift            4
# Kotlin           0
# Assembly         0

# %%
def getPercentages(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%".format(pct, absolute)

for i in range(len(df)):
    absolute = int(column/100.*np.sum(allvals))
    df.loc[i,Number] =  "{:.1f}%".format(pct, absolute)
df
# Out:
#             Number
# Python           0
# Javascript       3
# Java             0
# C/C++            4
# C#               5
# SQL              6
# PHP              7
# Matlab           3
# Swift            4
# Kotlin           0
# Assembly         0

# %%
def getPercentages(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%".format(pct, absolute)


plt = df.plot.pie(
    x = "languages", 
y = "Number", 
autopct=lambda pct: getPercentages(pct, data))

plt.legend(loc="center left",
          bbox_to_anchor=(1.1, 0, .5, 1))
plt.axis('off')
plt
# Out:
# <AxesSubplot:ylabel='Number'>

# %%
language = [0,3,0,4,5,6,7,3,4,0,0]
codingLanguages = [
        'Python',
        'Javascript',
        'Java',
        'C/C++',
        'C#',
        'SQL',
        'PHP',
        'Matlab',
        'Swift',
        'Kotlin',
        'Assembly',
]
df = pd.DataFrame(data = {"languages":codingLanguages, "Number":language}, index= codingLanguages)
#plt = df.plot.pie(x = "languages", y = "Number", title = "Languages from Indeed",legend = False)
plt = df.plot.pie(x = "languages", y = "Number", title = "Languages from Indeed",legend = False)
plt.axis('off')
# Out:
# (-1.25, 1.25, -1.25, 1.25)

# %%
df = pd.DataFrame(data = {"Languages":codingLanguages, "Amount":language})
plt = df.plot.bar(x = "Languages", y = "Amount", title = "Languages from Indeed",legend = False)
for i in range(len(codingLanguages)):
        plt.text(i,language[i],language[i],ha = 'center')
plt.set_ylabel("Amount")
plt
# Out:
# <AxesSubplot:title={'center':'Languages from Indeed'}, xlabel='Languages', ylabel='Amount'>
